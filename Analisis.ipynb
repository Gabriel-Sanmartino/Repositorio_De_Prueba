# %% [markdown]
# # Analisis estadistico dataset DatosFinalesFiltrados

# %%
# Importar librerias necesarias 

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as skl
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Importar librerias necesarias
# ----> 3 import pandas as pd
#       4 import numpy as np
#       5 import seaborn as sns
#
# File c:\Users\Maria\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\__init__.py:152
#     134 from pandas.core.reshape.api import (
#     135     concat,
#     136     lreshape,
#    (...)
#     148     qcut,
#     149 )
#     151 from pandas import api, arrays, errors, io, plotting, tseries
# --> 152 from pandas import testing
#     153 from pandas.util._print_versions import show_versions
#     155 from pandas.io.api import (
#     156     # excel
#     157     ExcelFile,
#    (...)
#     185     read_spss,
#     186 )
#
# File c:\Users\Maria\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\testing.py:6
#       1 """
# ...

# %% [markdown]
# Hola es un test de modificacion

# %%
# Ajustar configuracion de visualizacion de dataframe para visualizar todas las columnas
pd.set_option('display.max_columns', None)

# Leer archivo "DatosFinalesFiltrado.csv"
DF = pd.read_csv('DatosFinalesFiltrado.csv')

# Generar vista truncada DF
Vista_Truncada = DF.head()

# Extraer dimensiones DF
DimensionesDF = DF.shape

# Generar descripcion estadistica de DF
Descripcion_Estadistica_DF = DF.describe()

# Impresiones:

print("Vista Truncada")

print(Vista_Truncada)

print("Dimensiones")

print(DimensionesDF)

print('Descripcion estadistica')

Descripcion_Estadistica_DF
# Out:
# Vista Truncada
#          date location_key country_code country_name  new_confirmed  \
# 0  2021-01-02           AR           AR    Argentina           7767
# 1  2021-01-03           AR           AR    Argentina           4934
# 2  2021-01-04           AR           AR    Argentina          13953
# 3  2021-01-05           AR           AR    Argentina          14085
# 4  2021-01-06           AR           AR    Argentina          14496
#
#    new_deceased  cumulative_confirmed  cumulative_deceased  \
# 0           166                  7767                  166
# 1           157                 12701                  323
# 2           157                 26654                  480
# 3           160                 40739                  640
# 4           131                 55235                  771
#
#    cumulative_vaccine_doses_administered  population  population_male  \
# 0                                  20334    44938712         19523766
# ...
